# %% [markdown]
# <img src="newlogomioti.png" style="height: 100px">
# <center style="color:#888">Módulo Data Science in IoT<br/>Asignatura Machine learning 2 (Unsupervised learning)</center>
#
# # Challenge S6: Reglas de asociación para análisis de cesta de la compra

# %% [markdown]
# ## Objetivos
#
# El objetivo de este challenge es enfrentarse a un problema de generación de reglas de asociación real: a partir de datos de transacciones de compra de un supermercado, realizar un estudio de la cesta de la compra (*market basket analysis*) mediante la generación de reglas de asociación.

# %%
# Descomentar esto para instalar paquete mlxtend
#import sys
#!{sys.executable} -m pip install mlxtend

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

import pandas as pd

# %% [markdown]
# ## Carga de datos
#
# Para comenzar, cargamos el fichero de tickets de venta:

# %%
df = pd.read_excel('data/Online Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# Y lo convertimos al formato esperado por la librería de reglas de asociación

# %%
# Preprocesamiento y filtrado de columnas no útiles
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# Filtramos por país, agrupamos por ticket y transponemos
basket = (df[df['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                   0.0                            0.0
# 536840                                   0.0                            0.0
# 536861                                   0.0                            0.0
# 536967                                   0.0                            0.0
# 536983                                   0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                       0.0                          0.0
# 536840                                       0.0                          0.0
# 536861                                       0.0                          0.0
# 536967                                       0.0                          0.0
# 536983                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                             0.0                                 0.0
# 536840                             0.0                                 0.0
# 536861                             0.0                                 0.0
# 536967                             0.0                                 0.0
# 536983                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE SKULLS  ...  YULETIDE IMAGES GIFT WRAP SET  \
# InvoiceNo                                 ...
# 536527                               0.0  ...                            0.0
# 536840                               0.0  ...                            0.0
# 536861                               0.0  ...                            0.0
# 536967                               0.0  ...                            0.0
# 536983                               0.0  ...                            0.0
#
# Description  ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536527                              0.0                        0.0
# 536840                              0.0                        0.0
# 536861                              0.0                        0.0
# 536967                              0.0                        0.0
# 536983                              0.0                        0.0
#
# Description  ZINC BOX SIGN HOME  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536527                      0.0                        0.0
# 536840                      0.0                        0.0
# 536861                      0.0                        0.0
# 536967                      0.0                        0.0
# 536983                      0.0                        0.0
#
# Description  ZINC HEART LATTICE T-LIGHT HOLDER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536527                                     0.0                          0.0
# 536840                                     0.0                          0.0
# 536861                                     0.0                          0.0
# 536967                                     0.0                          0.0
# 536983                                     0.0                          0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536527                                  0.0                              0.0
# 536840                                  0.0                              0.0
# 536861                                  0.0                              0.0
# 536967                                  0.0                              0.0
# 536983                                  0.0                              0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
#
# [5 rows x 1695 columns]

# %%
# Convertimos los binarios a enteros
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                            0                           0
# 536840                            0                           0
# 536861                            0                           0
# 536967                            0                           0
# 536983                            0                           0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                      0
# 536840                                      0
# 536861                                      0
# 536967                                      0
# 536983                                      0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                     0                              0
# 536840                                     0                              0
# 536861                                     0                              0
# 536967                                     0                              0
# 536983                                     0                              0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                         0                            0
# 536840                                         0                            0
# 536861                                         0                            0
# 536967                                         0                            0
# 536983                                         0                            0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                               0                                   0
# 536840                               0                                   0
# 536861                               0                                   0
# 536967                               0                                   0
# 536983                               0                                   0
#
# Description  12 PENCILS TALL TUBE SKULLS                ...                 \
# InvoiceNo                                               ...
# 536527                                 0                ...
# 536840                                 0                ...
# 536861                                 0                ...
# 536967                                 0                ...
# 536983                                 0                ...
#
# Description  YULETIDE IMAGES GIFT WRAP SET  ZINC  HEART T-LIGHT HOLDER  \
# InvoiceNo
# 536527                                   0                           0
# 536840                                   0                           0
# 536861                                   0                           0
# 536967                                   0                           0
# 536983                                   0                           0
#
# Description  ZINC  STAR T-LIGHT HOLDER  ZINC BOX SIGN HOME  \
# InvoiceNo
# 536527                               0                   0
# 536840                               0                   0
# 536861                               0                   0
# 536967                               0                   0
# 536983                               0                   0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# InvoiceNo
# 536527                               0                                  0
# 536840                               0                                  0
# 536861                               0                                  0
# 536967                               0                                  0
# 536983                               0                                  0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536527                                 0                               0
# 536840                                 0                               0
# 536861                                 0                               0
# 536967                                 0                               0
# 536983                                 0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                     0                                 0
# 536840                                     0                                 0
# 536861                                     0                                 0
# 536967                                     0                                 0
# 536983                                     0                                 0
#
# [5 rows x 1694 columns]

# %% [markdown]
# * ¿Cuál es el tamaño de nuestro conjunto de items $I$ ?

# %%
len(basket_sets.index)
# Out:
# 457

# %% [markdown]
# * ¿ Cuál es el tamaño de nuestro conjunto de transacciones $D$ ?

# %%
len(basket_sets.columns)
# Out:
# 1694

# %% [markdown]
# ## Reglas de asociación con mlxtend
#
# Ahora vamos a utilizar la librería [`mlxtend`](http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/) para generar las reglas de asociación más interesantes en nuestro conjunto de datos.
#
# * Comenzamos calculando el soporte de los itemsets frecuentes de nuestro conjunto, aplicando un umbral mínimo de 0.07:

# %%
frequent_itemsets_07 = apriori(basket_sets, min_support=0.07, use_colnames=True)
frequent_itemsets_07
# Out:
#      support                                           itemsets
# 0   0.102845                           (6 RIBBONS RUSTIC CHARM)
# 1   0.070022                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.072210                                (GUMBALL COAT RACK)
# 3   0.091904                           (JAM MAKING SET PRINTED)
# 4   0.078775                          (JUMBO BAG RED RETROSPOT)
# 5   0.100656                       (JUMBO BAG WOODLAND ANIMALS)
# 6   0.078775                               (LUNCH BAG WOODLAND)
# 7   0.085339                  (PACK OF 72 RETROSPOT CAKE CASES)
# 8   0.115974                    (PLASTERS IN TIN CIRCUS PARADE)
# 9   0.107221                         (PLASTERS IN TIN SPACEBOY)
# 10  0.070022                        (PLASTERS IN TIN STRONGMAN)
# 11  0.137856                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 12  0.070022                      (RED RETROSPOT CHARLOTTE BAG)
# 13  0.070022                                (RED RETROSPOT CUP)
# 14  0.096280                    (RED TOADSTOOL LED NIGHT LIGHT)
# 15  0.137856                         (REGENCY CAKESTAND 3 TIER)
# 16  0.157549                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 17  0.245077               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 18  0.070022                       (SET OF 3 REGENCY CAKE TINS)
# 19  0.102845                               (SPACEBOY LUNCH BOX)
# 20  0.078775                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 21  0.126915                           (WOODLAND CHARLOTTE BAG)
# 22  0.074398  (PLASTERS IN TIN WOODLAND ANIMALS, ROUND SNACK...
# 23  0.131291  (ROUND SNACK BOXES SET OF 4 FRUITS, ROUND SNAC...
# 24  0.070022  (SPACEBOY LUNCH BOX, ROUND SNACK BOXES SET OF4...

# %% [markdown]
# * Prueba a ejecutar el mismo algoritmo apriori con umbral mínimo de soporte de 0.05 y 0.09. ¿Qué observas? ¿A qué crees que se debe?

# %%
frequent_itemsets_05 = apriori(basket_sets, min_support=0.05, use_colnames=True)
print(frequent_itemsets_05.tail())
frequent_itemsets_09 = apriori(basket_sets, min_support=0.09, use_colnames=True)
print(frequent_itemsets_09.tail())
# Out:
#      support                                           itemsets
# 54  0.074398  (PLASTERS IN TIN WOODLAND ANIMALS, ROUND SNACK...
# 55  0.059081  (RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOT...
# 56  0.131291  (ROUND SNACK BOXES SET OF 4 FRUITS, ROUND SNAC...
# 57  0.070022  (SPACEBOY LUNCH BOX, ROUND SNACK BOXES SET OF4...
# 58  0.063457  (WOODLAND CHARLOTTE BAG, ROUND SNACK BOXES SET...
#      support                                           itemsets
# 8   0.157549                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 9   0.245077               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 10  0.102845                               (SPACEBOY LUNCH BOX)
# 11  0.126915                           (WOODLAND CHARLOTTE BAG)
# 12  0.131291  (ROUND SNACK BOXES SET OF 4 FRUITS, ROUND SNAC...

# %%
#Cuanto mas bajo el valor de min_support menos valores vamos a obtener

# %% [markdown]
# De ahora en adelante utilizaremos el primer soporte calculado con un umbral de valor 0.07.
#
# * ¿Cuál es el item con mayor valor de soporte?

# %%
#frequent_itemsets_07.support.sort_values(ascending=False)
frequent_itemsets_07[['support','itemsets']].sort_values(by='support', ascending=False).head(5)
# Out:
#      support                                           itemsets
# 17  0.245077               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 16  0.157549                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 15  0.137856                         (REGENCY CAKESTAND 3 TIER)
# 11  0.137856                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 23  0.131291  (ROUND SNACK BOXES SET OF 4 FRUITS, ROUND SNAC...

# %% [markdown]
# * Ahora vamos a calcular las reglas de asociación utilizando el soporte calculado previamente. Prueba utilizando la métrica confidence con un umbral mínimo de 1.

# %%
as_conf = association_rules(frequent_itemsets_07, metric="confidence", min_threshold=1.0)
as_conf
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# * Ahora prueba utilizando la métrica lift con un umbral mínimo de 1.

# %%
as_lift = association_rules(frequent_itemsets_07, metric="lift", min_threshold=1.0)
as_lift
# Out:
#                             antecedents                           consequents  \
# 0    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 1  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 2   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 4                  (SPACEBOY LUNCH BOX)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 5  (ROUND SNACK BOXES SET OF4 WOODLAND)                  (SPACEBOY LUNCH BOX)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.137856            0.245077  0.074398    0.539683  2.202098
# 1            0.245077            0.137856  0.074398    0.303571  2.202098
# 2            0.157549            0.245077  0.131291    0.833333  3.400298
# 3            0.245077            0.157549  0.131291    0.535714  3.400298
# 4            0.102845            0.245077  0.070022    0.680851  2.778116
# 5            0.245077            0.102845  0.070022    0.285714  2.778116
#
#    leverage  conviction
# 0  0.040613    1.640006
# 1  0.040613    1.237951
# 2  0.092679    4.529540
# 3  0.092679    1.814509
# 4  0.044817    2.365427
# 5  0.044817    1.256018

# %% [markdown]
# * Sobre estas últimas reglas calculadas, filtra aquellas que tengan un lift mayor que 1.5 y un confidence mayor que 0.7

# %%
as_lift[ (as_lift['confidence'] > 0.7) & (as_lift['lift'] > 1.5) ]
# Out:
#                            antecedents                           consequents  \
# 2  (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 2            0.157549            0.245077  0.131291    0.833333  3.400298
#
#    leverage  conviction
# 2  0.092679     4.52954

# %% [markdown]
# * ¿Cómo intepretarías el significado en concreto de estas reglas de asociación generadas?

# %% [markdown]
# Que las dos cajas de frutas y comidas se suelen comprar juntas un 80% de las veces. Al tener un valor de lift alto también explica la dependencia entre ambos productos.

# %% [markdown]
# ## Reglas de asociación a mano
#
# Tomemos como ejemplo la regla de asociación generada en el paso previo. Vamos a realizar los cálculos previamente obtenidos por `mlxtend`, ahora nosotros a mano.
#
# * Comenzamos por el soporte. Calcula el soporte del antecedente, del consecuente y de ambos, de la última regla de asociación (sin utilizar mlxtend).

# %%
a = basket_sets[basket_sets['ROUND SNACK BOXES SET OF 4 FRUITS'] == 1].size / basket_sets.size
a
# Out:
# 0.1575492341356674

# %%
b =(basket_sets['ROUND SNACK BOXES SET OF4 WOODLAND'] & basket_sets['ROUND SNACK BOXES SET OF 4 FRUITS']).sum() / basket_sets.shape[0]
b
# Out:
# 0.13129102844638948

# %% [markdown]
# * Una vez calculado los soportes, calcula la confianza (confidence) de la regla.

# %%
b/a
# Out:
# 0.8333333333333333

# %% [markdown]
# * Ahora calcula el lift.

# %%
# Out:
# 0.1890590809628009

# %% [markdown]
# Comprueba que obtienes los mismos resultados que con `mlxtend`.

# %% [markdown]
# ## Opcional
#
# * Utilizando los datos calculados por `mlxtend`, realizar un scatter plot que represente el `confidence` frente al `lift` de las reglas de asociación obtenidas.
#
# * En el análisis realizado previamente, se filtraron las ventas únicamente de Alemania. Calcular las reglas de asociación para otro país y comparar los resultados obtenidos con los de antes.

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

ax = sns.scatterplot(x='confidence', y='lift', data=as_lift)

# %%
# Repetir para otro pais

# %%
# Preprocesamiento y filtrado de columnas no útiles
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# Filtramos por país, agrupamos por ticket y transponemos
basket2 = (df[df['Country'] =="Spain"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket2.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536944                          0.0                        0.0
# 538095                          0.0                        0.0
# 538525                          0.0                        0.0
# 539351                          0.0                        0.0
# 540469                          0.0                        0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536944                                   0.0                            0.0
# 538095                                   0.0                            0.0
# 538525                                   0.0                            0.0
# 539351                                   0.0                            0.0
# 540469                                   0.0                            0.0
#
# Description  20 DOLLY PEGS RETROSPOT  200 RED + WHITE BENDY STRAWS  \
# InvoiceNo
# 536944                           0.0                           0.0
# 538095                           0.0                           0.0
# 538525                           0.0                           0.0
# 539351                           0.0                           0.0
# 540469                           0.0                           0.0
#
# Description  3 DRAWER ANTIQUE WHITE WOOD CABINET  3 HOOK HANGER MAGIC GARDEN  \
# InvoiceNo
# 536944                                       0.0                         0.0
# 538095                                       0.0                         0.0
# 538525                                       0.0                         0.0
# 539351                                       0.0                         0.0
# 540469                                       0.0                         0.0
#
# Description  3 HOOK PHOTO SHELF ANTIQUE WHITE  \
# InvoiceNo
# 536944                                    0.0
# 538095                                    0.0
# 538525                                    0.0
# 539351                                    0.0
# 540469                                    0.0
#
# Description  3 PIECE SPACEBOY COOKIE CUTTER SET  ...  WRAP RED APPLES  \
# InvoiceNo                                        ...
# 536944                                      0.0  ...              0.0
# 538095                                      0.0  ...              0.0
# 538525                                      0.0  ...              0.0
# 539351                                      0.0  ...              0.0
# 540469                                      4.0  ...              0.0
#
# Description  WRAP RED VINTAGE DOILY  WRAP SUKI AND FRIENDS  \
# InvoiceNo
# 536944                          0.0                    0.0
# 538095                          0.0                    0.0
# 538525                          0.0                    0.0
# 539351                          0.0                    0.0
# 540469                          0.0                    0.0
#
# Description  WRAP, BILLBOARD FONTS DESIGN  YELLOW COAT RACK PARIS FASHION  \
# InvoiceNo
# 536944                                0.0                             0.0
# 538095                                0.0                             1.0
# 538525                                0.0                             0.0
# 539351                                0.0                             0.0
# 540469                                0.0                             0.0
#
# Description  YELLOW FLOWERS FELT HANDBAG KIT  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536944                                   0.0                        0.0
# 538095                                   0.0                        0.0
# 538525                                   0.0                        0.0
# 539351                                   0.0                        0.0
# 540469                                   4.0                        0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536944                               0.0                             0.0
# 538095                               0.0                             0.0
# 538525                               0.0                             0.0
# 539351                               0.0                             0.0
# 540469                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536944                                   0.0
# 538095                                   0.0
# 538525                                   0.0
# 539351                                   0.0
# 540469                                   0.0
#
# [5 rows x 1104 columns]

# %%
basket_sets2 = basket2.applymap(encode_units)
basket_sets2.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_sets2.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536944                            0                          0
# 538095                            0                          0
# 538525                            0                          0
# 539351                            0                          0
# 540469                            0                          0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536944                                     0                              0
# 538095                                     0                              0
# 538525                                     0                              0
# 539351                                     0                              0
# 540469                                     0                              0
#
# Description  20 DOLLY PEGS RETROSPOT  200 RED + WHITE BENDY STRAWS  \
# InvoiceNo
# 536944                             0                             0
# 538095                             0                             0
# 538525                             0                             0
# 539351                             0                             0
# 540469                             0                             0
#
# Description  3 DRAWER ANTIQUE WHITE WOOD CABINET  3 HOOK HANGER MAGIC GARDEN  \
# InvoiceNo
# 536944                                         0                           0
# 538095                                         0                           0
# 538525                                         0                           0
# 539351                                         0                           0
# 540469                                         0                           0
#
# Description  3 HOOK PHOTO SHELF ANTIQUE WHITE  \
# InvoiceNo
# 536944                                      0
# 538095                                      0
# 538525                                      0
# 539351                                      0
# 540469                                      0
#
# Description  3 PIECE SPACEBOY COOKIE CUTTER SET  ...  WRAP RED APPLES  \
# InvoiceNo                                        ...
# 536944                                        0  ...                0
# 538095                                        0  ...                0
# 538525                                        0  ...                0
# 539351                                        0  ...                0
# 540469                                        1  ...                0
#
# Description  WRAP RED VINTAGE DOILY  WRAP SUKI AND FRIENDS  \
# InvoiceNo
# 536944                            0                      0
# 538095                            0                      0
# 538525                            0                      0
# 539351                            0                      0
# 540469                            0                      0
#
# Description  WRAP, BILLBOARD FONTS DESIGN  YELLOW COAT RACK PARIS FASHION  \
# InvoiceNo
# 536944                                  0                               0
# 538095                                  0                               1
# 538525                                  0                               0
# 539351                                  0                               0
# 540469                                  0                               0
#
# Description  YELLOW FLOWERS FELT HANDBAG KIT  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536944                                     0                          0
# 538095                                     0                          0
# 538525                                     0                          0
# 539351                                     0                          0
# 540469                                     1                          0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536944                                 0                               0
# 538095                                 0                               0
# 538525                                 0                               0
# 539351                                 0                               0
# 540469                                 0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536944                                     0
# 538095                                     0
# 538525                                     0
# 539351                                     0
# 540469                                     0
#
# [5 rows x 1103 columns]

# %%
frequent_itemsets_07_spain = apriori(basket_sets2, min_support=0.07, use_colnames=True)

# %%
frequent_itemsets_07_spain[['support','itemsets']].sort_values(by='support', ascending=False).head(5)
# Out:
#      support                              itemsets
# 21  0.244444            (REGENCY CAKESTAND 3 TIER)
# 0   0.166667              (6 RIBBONS RUSTIC CHARM)
# 6   0.155556            (JAM MAKING SET WITH JARS)
# 23  0.133333  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 32  0.133333                  (SPACEBOY LUNCH BOX)

# %%
as_conf = association_rules(frequent_itemsets_07_spain, metric="confidence", min_threshold=1.0)
as_conf
# Out:
#                    antecedents                  consequents  \
# 0  (POPPY'S PLAYHOUSE KITCHEN)  (POPPY'S PLAYHOUSE BEDROOM)
#
#    antecedent support  consequent support   support  confidence   lift  \
# 0            0.077778            0.088889  0.077778         1.0  11.25
#
#    leverage  conviction
# 0  0.070864         inf

# %%
as_lift = association_rules(frequent_itemsets_07_spain, metric="lift", min_threshold=1.0)
as_lift
# Out:
#                        antecedents                      consequents  \
# 0  (ASSORTED COLOUR BIRD ORNAMENT)         (6 RIBBONS RUSTIC CHARM)
# 1         (6 RIBBONS RUSTIC CHARM)  (ASSORTED COLOUR BIRD ORNAMENT)
# 2      (POPPY'S PLAYHOUSE KITCHEN)      (POPPY'S PLAYHOUSE BEDROOM)
# 3      (POPPY'S PLAYHOUSE BEDROOM)      (POPPY'S PLAYHOUSE KITCHEN)
#
#    antecedent support  consequent support   support  confidence   lift  \
# 0            0.133333            0.166667  0.100000       0.750   4.50
# 1            0.166667            0.133333  0.100000       0.600   4.50
# 2            0.077778            0.088889  0.077778       1.000  11.25
# 3            0.088889            0.077778  0.077778       0.875  11.25
#
#    leverage  conviction
# 0  0.077778    3.333333
# 1  0.077778    2.166667
# 2  0.070864         inf
# 3  0.070864    7.377778

# %%
as_lift[ (as_lift['confidence'] > 0.7) & (as_lift['lift'] > 1.5) ]
# Out:
#                        antecedents                  consequents  \
# 0  (ASSORTED COLOUR BIRD ORNAMENT)     (6 RIBBONS RUSTIC CHARM)
# 2      (POPPY'S PLAYHOUSE KITCHEN)  (POPPY'S PLAYHOUSE BEDROOM)
# 3      (POPPY'S PLAYHOUSE BEDROOM)  (POPPY'S PLAYHOUSE KITCHEN)
#
#    antecedent support  consequent support   support  confidence   lift  \
# 0            0.133333            0.166667  0.100000       0.750   4.50
# 2            0.077778            0.088889  0.077778       1.000  11.25
# 3            0.088889            0.077778  0.077778       0.875  11.25
#
#    leverage  conviction
# 0  0.077778    3.333333
# 2  0.070864         inf
# 3  0.070864    7.377778
