# %% [markdown]
# ##### <img src="mioti.png" style="height: 100px">
# <center style="color:#888">Módulo Data Science in IoT<br/>Asignatura Data preprocessing</center>
# # Challenge S5: Liga de Fútbol Profesional

# %% [markdown]
# ## Objetivos
#
# El objetivo de este challenge es simular mediante el método de montecarlo el resultado de la próxima liga 2019-2020.
#
# Para ello, utilizando las distribuciones de probabilidad, y todos los conceptos previos que hemos aprendido realizaremos una simulación lo más realista posible.

# %% [markdown]
# ## Configuración del entorno

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Carga de datos
#
# Para este challenge dispones de varias fuentes de datos que puedes utilizar:
#
# * `equipos_liga_2019-20.txt` Fichero TXT con los equipos que disputarán la temporada 2010 - 2020 en la primera división de Liga de Fútbol profesional en España.
# * `clasificacion_historica.csv` Fichero con resultados acumulados de todos los equipos que han jugado alguna vez en primera division.
# * Cualquier otra fuente de datos que quieras añadir o información tuya si sabes mucho de fútbol 😄.

# %% [markdown]
# El primer paso será la carga de datos a partir del fichero `TXT`. Como sólo contiene el nombre de los equipos meteremos los valores en una lista.

# %%
with open('equipos_liga_2019-20.txt', encoding='utf-8') as f:
    equipos = f.readlines()
    equipos = [x.strip() for x in equipos] 

equipos
# Out:
# ['D. Alavés',
#  'Athletic Club',
#  'Atlético de Madrid',
#  'FC Barcelona',
#  'Real Betis',
#  'RC Celta',
#  'SD Eibar',
#  'RCD Espanyol',
#  'Getafe CF',
#  'Granada CF',
#  'CD Leganés',
#  'Levante UD',
#  'RCD Mallorca',
#  'C.A. Osasuna',
#  'Real Madrid',
#  'Real Sociedad',
#  'R. Valladolid CF',
#  'Sevilla FC',
#  'Valencia CF',
#  'Villarreal CF']

# %% [markdown]
# ## Simulador de partidos
#
# El primer paso para realizar un análisis de montecarlo es definir la función que nos permita simular cada caso individual, en nuestro casos son los partidos. Puedes implementar esta función como quieras.
#
# Tip: puedes usar `clasificacion_historica.csv` que contiene datos históricos de los distintos equipos, usar una fuente que busques por internet, o puedes hacer una función con tu "conocimiento futbolístico".

# %%
clashist=pd.read_csv("clasificacion_historica.csv",sep='\t')

# %% [markdown]
# Podemos ver los datos de clasificación histórica de los equipos que jugarán la liga la próxima temporada

# %%
df = clashist[clashist.Equipo.isin(equipos)]

# %%
# Sacamos el ratio de partidos ganados / empatados y perdidos. Esto ya nos da una idea de quien es el mejor :)

df_filtered = df.copy()
df_filtered['PG_ratio'] = df_filtered['PG'] / df_filtered['PJ']
df_filtered['PE_ratio'] = df_filtered['PE'] / df_filtered['PJ']
df_filtered['PP_ratio'] = df_filtered['PP'] / df_filtered['PJ']
df_filtered
# Out:
#     Pos              Equipo  Ptos    PJ    PG   PE    PP    GF    GC    DG  \
# 0    1º         Real Madrid  4529  2838  1690  567   581  6104  3230  2874
# 1    2º        FC Barcelona  4442  2838  1635  578   625  6089  3179  2910
# 2    3º  Atlético de Madrid  3597  2690  1286  618   786  4647  3360  1287
# 3    4º         Valencia CF  3520  2740  1224  639   877  4514  3542   972
# 4    5º       Athletic Club  3464  2838  1232  660   946  4713  3794   919
# 5    6º          Sevilla FC  2936  2484  1024  546   914  3791  3478   313
# 6    7º        RCD Espanyol  2894  2702   974  632  1096  3693  3976  -283
# 7    8º       Real Sociedad  2672  2378   891  595   892  3339  3335     4
# 9   10º          Real Betis  1995  1804   638  454   712  2266  2604  -338
# 10  11º            RC Celta  1879  1774   609  410   755  2390  2747  -357
# 12  13º    R. Valladolid CF  1512  1504   473  395   636  1797  2233  -436
# 15  16º        C.A. Osasuna  1348  1316   425  326   565  1497  1833  -336
# 17  18º        RCD Mallorca  1148   988   333  256   399  1182  1371  -189
# 18  19º       Villarreal CF  1075   722   294  193   235   998   891   107
# 22  23º           Getafe CF   667   532   177  136   219   610   701   -91
# 23  24º          Granada CF   667   742   218  175   349   819  1158  -339
# 27  28º           D. Alavés   518   456   153   94   209   537   728  -191
# 29  30º          Levante UD   506   478   135  119   224   533   756  -223
# 38  39º            SD Eibar   230   190    60   50    80   229   267   -38
# 45  46º          CD Leganés   123   114    31   30    53   107   149   -42
#
#     PG_ratio  PE_ratio  PP_ratio
# 0   0.595490  0.199789  0.204722
# 1   0.576110  0.203665  0.220226
# 2   0.478067  0.229740  0.292193
# 3   0.446715  0.233212  0.320073
# 4   0.434109  0.232558  0.333333
# 5   0.412238  0.219807  0.367955
# 6   0.360474  0.233901  0.405625
# 7   0.374685  0.250210  0.375105
# 9   0.353659  0.251663  0.394678
# 10  0.343292  0.231116  0.425592
# 12  0.314495  0.262633  0.422872
# 15  0.322948  0.247720  0.429331
# 17  0.337045  0.259109  0.403846
# 18  0.407202  0.267313  0.325485
# 22  0.332707  0.255639  0.411654
# 23  0.293801  0.235849  0.470350
# 27  0.335526  0.206140  0.458333
# 29  0.282427  0.248954  0.468619
# 38  0.315789  0.263158  0.421053
# 45  0.271930  0.263158  0.464912

# %% [markdown]
# Lo primero es simular un partido entre 2 equipos

# %%
from random import randint
def simular_partido(equipo_local, equipo_visitante):
    '''Simula un partido, devuelve una entero: 0 gana el equipo local, 1 empate, 2 gana el equipo visitante'''
    
    tipos_resultados = [0, 1, 2] # Posibles valores (gana local, empate, gana_vistante)
    tipos_resultados_p = [0.8, 0.1, 0.1]    
    
    local = df_filtered['Equipo'] == equipo_local
    visitante = df_filtered['Equipo'] == equipo_visitante
    resultado = 0
    
    diff_w = df_filtered[local].PG_ratio.values - df_filtered[visitante].PG_ratio.values
    diff_l = df_filtered[local].PP_ratio.values - df_filtered[visitante].PP_ratio.values
    if (df_filtered[local].PG_ratio.values > df_filtered[visitante].PG_ratio.values):
        if (diff_w > 0.17):
            resultado = np.random.choice(tipos_resultados, 1, p=tipos_resultados_p)
        else:
            resultado = randint(0,2)
    elif (df_filtered[local].PG_ratio.values < df_filtered[visitante].PG_ratio.values):
        if (diff_w > -0.17):
            resultado = 2
        else:
            resultado = randint(0,2) 
    return resultado

# %%
simular_partido('Real Madrid', 'FC Barcelona')
# Out:
# 2

# %% [markdown]
# ## Simulador de temporadas
#
# Una vez que tenemos una función que nos simula un partido, vamos a hacer una función que nos simule una temporada completa `simular_temporada`:

# %%
def simular_temporada():
    '''Simula una temporada completa, y devuelve un diccionario con el resultado en puntos obtenido por cada equipo'''
    
    # Creo una clasificación vacía (diccionario con puntos)
    clasificacion = {}
    for e in equipos:
        clasificacion[e] = 0 

    for equipo_local in equipos:
        for equipo_visitante in equipos:
            if equipo_local == equipo_visitante:
                pass
            resultado = simular_partido(equipo_local, equipo_visitante)
            
            if resultado == 0: 
                # Gana el equipo local
                clasificacion[equipo_local] += 3
            elif resultado == 1: 
                # Empate
                clasificacion[equipo_local] += 1
                clasificacion[equipo_visitante] += 1
            elif resultado == 2:
                # Gana el equipo visitante
                clasificacion[equipo_visitante] += 3
                
    return clasificacion

# %% [markdown]
# ## Agregador de resultados
# Por último necesitamos una función (`simular_lfp`) que nos genere los distintos casos de prueba a evaluar (temporadas) y por cada una de ella nos agrege los resultados

# %%
def simular_lfp(num_iteraciones):
    '''
    Realiza la simulación de montecarlo
    Devuelve un dataframe que tiene por columnas los distintos equipos y por cada fila la posición
    de cada equipo en la simulación.
    '''
    # Creo una clasificación global vacía
    clasificacion_global = pd.DataFrame(columns=equipos)

    num_intentos = 0
    for intento in range(0, num_iteraciones):
        if intento % 5 == 0:
            print("Simulando temporada " + str(intento) + "...")

        # Obtenemos los resultados de puntos de la temporada
        temporada_i = simular_temporada()     
        #print("Resultados: " + str(temporada_i))

        # Convertimos los puntos en clasificacion
        clasificacion = {}
        posicion = 1
        for equipo in sorted(temporada_i, key=temporada_i.get, reverse=True):
            clasificacion[equipo] = posicion
            posicion += 1

        #print("Clasificación: " + str(clasificacion))

        # Obtengo el equipo ganador
        clasificacion_global.loc[intento] = clasificacion

        num_intentos += 1

    #print(clasificacion_global)
    print("Fin de la simulación.")
    return clasificacion_global

# %% [markdown]
# ## Ejecución del análisis

# %%
clasificacion_global = simular_lfp(110)
# Out:
# Simulando temporada 0...
# Simulando temporada 5...
# Simulando temporada 10...
# Simulando temporada 15...
# Simulando temporada 20...
# Simulando temporada 25...
# Simulando temporada 30...
# Simulando temporada 35...
# Simulando temporada 40...
# Simulando temporada 45...
# Simulando temporada 50...
# Simulando temporada 55...
# Simulando temporada 60...
# Simulando temporada 65...
# Simulando temporada 70...
# Simulando temporada 75...
# Simulando temporada 80...
# Simulando temporada 85...
# Simulando temporada 90...
# Simulando temporada 95...
# Simulando temporada 100...
# Simulando temporada 105...
# Fin de la simulación.

# %%
clasificacion_global.head(20)
# Out:
#    D. Alavés Athletic Club Atlético de Madrid FC Barcelona Real Betis  \
# 0         13             4                  1            5         12
# 1         12             4                  8            5         13
# 2         15             4                  2            5         10
# 3         12             6                  3            4         11
# 4         14             4                  1            7          8
# 5         13             4                  2            3         10
# 6         14             6                  1            3         10
# 7         11             6                  2            3         13
# 8         12             2                  1            6         11
# 9         16             3                  4            1          5
# 10        16             3                  6            1         10
# 11        14             6                  5            2         12
# 12        12             3                  4            6          9
# 13        14             8                  2            5         10
# 14        14             1                  4            3          9
# 15        13             4                  5            1         10
# 16        13             8                  6           11          9
# 17        15             8                  3            1         10
# 18        13             7                  5            3          8
# 19        12            10                  1            2          7
#
#    RC Celta SD Eibar RCD Espanyol Getafe CF Granada CF CD Leganés Levante UD  \
# 0         9       14           10        16         17         20         18
# 1        10       15            9        14         17         20         19
# 2        11       13            8        16         18         20         19
# 3         9       13           10        15         19         20         17
# 4        10       15           11        12         18         20         17
# 5        12       14           11        15         19         18         20
# 6         7       15           13        16         17         19         20
# 7        12       14            9        15         18         20         17
# 8         9       14            7        13         17         20         18
# 9        11       14           10        12         15         20         19
# 10        9       19           11        13         17         18         20
# 11        9       15           11        13         19         20         18
# 12        7       16            2        15         18         19         20
# 13       12       18            9        13         15         20         19
# 14       12       16           11        13         17         20         18
# 15        8       16            9        14         20         19         17
# 16       12       16            2        15         17         19         20
# 17       12       16            5        11         18         19         20
# 18       14       15            9        16         17         19         20
# 19       13       18            8        14         17         19         20
#
#    RCD Mallorca C.A. Osasuna Real Madrid Real Sociedad R. Valladolid CF  \
# 0            11           15           3             7               19
# 1            11           18           2             7               16
# 2            12           14           1             6               17
# 3            14           16           2             7               18
# 4            13           19           2             9               16
# 5             8           16           1             7               17
# 6            11           12           5             8               18
# 7            10           19           1             5               16
# 8            15           16           3             8               19
# 9            13           17           6             7               18
# 10           14           12           7             8               15
# 11           10           16           1             7               17
# 12           14           13           5            11               17
# 13           11           16           1             4               17
# 14           10           15           5             6               19
# 15           15           12           2            11               18
# 16           10           14           1             7               18
# 17           13           14           2             9               17
# 18           10           12           4            11               18
# 19            9           15           4            11               16
#
#    Sevilla FC Valencia CF Villarreal CF
# 0           8           6             2
# 1           3           1             6
# 2           9           7             3
# 3           8           1             5
# 4           6           5             3
# 5           6           5             9
# 6           2           4             9
# 7           8           4             7
# 8           4           5            10
# 9           9           2             8
# 10          5           2             4
# 11          3           4             8
# 12         10           1             8
# 13          3           7             6
# 14          8           2             7
# 15          6           3             7
# 16          5           3             4
# 17          6           7             4
# 18          2           1             6
# 19          3           5             6

# %% [markdown]
# ## Análisis de resultados
#
# Ahora, con los resultados obtenidos, vamos a plantearnos algunas preguntas:
#
# ### ¿Cuál es la posición media de cada equipo en la simulación?

# %%
clasificacion_global.mean(axis=0)
# Out:
# D. Alavés             13.063636
# Athletic Club          4.672727
# Atlético de Madrid     2.827273
# FC Barcelona           3.772727
# Real Betis             9.554545
# RC Celta              10.918182
# SD Eibar              15.700000
# RCD Espanyol           8.554545
# Getafe CF             14.054545
# Granada CF            17.427273
# CD Leganés            19.218182
# Levante UD            18.563636
# RCD Mallorca          12.118182
# C.A. Osasuna          15.200000
# Real Madrid            2.990909
# Real Sociedad          8.009091
# R. Valladolid CF      17.054545
# Sevilla FC             5.690909
# Valencia CF            4.009091
# Villarreal CF          6.600000
# dtype: float64

# %% [markdown]
# ### ¿Ha ganado R. Valladolid CF alguna vez la liga?

# %%
# No, su mejor posicion ha sido quedar en undecimo lugar una temporada
clasificacion_global['Real Madrid'].value_counts()
# Out:
# 1    30
# 2    23
# 4    18
# 3    18
# 5    10
# 7     6
# 6     3
# 9     1
# 8     1
# Name: Real Madrid, dtype: int64

# %% [markdown]
# ### ¿Cual es la distribución de los resultados del Madrid, Barcelona y del SD Eibar?

# %%
#dist = clasificacion_global['Real Madrid','FC Barcelona','SD Eibar']

dist = clasificacion_global[['Real Madrid', 'FC Barcelona', 'SD Eibar']].copy()
dist['Real Madrid'].plot.hist()
# Distribucion de Pareto

# %%
dist['FC Barcelona'].plot.hist()
# Distribucion "Pareto"

# %%
dist['SD Eibar'].plot.hist()
# Distribucion Normal

# %% [markdown]
# ## Reflexiones
#
# * ¿Qué información se te ocurre que puede ser interesante incorporar en esta simulación?
# * ¿Puede el método de montecarlo ayudarnos a ganar una quiniela?

# %% [markdown]
# Bajo mi punto de vista hacen falta mas datos para tener unos datos mas precisos, teniendo en cuenta que hay un factor de suerte, azar que no es controlable.
# Por ejemplo, un listado con los ultimos 5 enfrentamientos de los equipos y el resultado mas repetido (1 X 2). Otro factor que podria ser interesante, es en que fecha se enfrentan que equipos, por ejemplo a principios de temporada es mas probable que un equipo de menor categoria gane a un equipo grande, dado que estos ultimos tienen que planificar temporadas con mas partiodos y suelen coger el pico de forma mas tarde.
#
# Puede darte una idea si no tienes ni idea de futbol, de ahi a ganar una quiniela de 15 resultados incluyendo 2 division que es todavia mas imprevisible va un mundo.
#
# Si bien la funcion no es muy compleja, si que refleja bastante bien la realidad de todos los equipos.
