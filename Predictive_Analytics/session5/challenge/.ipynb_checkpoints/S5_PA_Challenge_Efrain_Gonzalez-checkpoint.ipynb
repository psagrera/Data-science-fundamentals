# %% [markdown]
# ##### <img src="mioti.png" style="height: 100px">
#
# # Challenge S5: Modelos regresivos aplicados a series temporales
#
# ## Nombre: Efrain Gonzalez

# %% [markdown]
# ## Objetivo
#
# El objetivo de este challenge es usar nuestro dataframe de ventas en retail y hacer un modelo para la predicción de ventas para un artículo distinto del que vimos en el worksheet.
#
# Tendréis que explorar los datos para ver el comportamiento del artículo elegido y las peculiaridades que pueda tener.
#
# Luego tendréis que hacer un modelo que pueda predecir las ventas de este artículo usando todo lo aprendido anteriormente, probando distintos modelos, hiperparametrizándolos y por último añadiendo todas las variables sintéticas que veáis convenientes para que el modelo aprenda mejor del comportamiento de las unidades vendidas del producto.

# %% [markdown]
# ## 1. Configuración del entorno
#
# Cargamos los paquetes que vamos a utilizar en la sesión.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_log_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 2. Carga de los datos, filtrado de nuestro artículo y visualización de los datos

# %% [markdown]
# **Carga el dataframe**

# %%
dataRetail = pd.read_csv('Dataframe_Retail.csv', delimiter=',')
print(dataRetail['Referencia'].unique())
# Out:
# ['Cerveza tercio' 'Baguetes 2 unidades' 'Aceite de oliva virgen extra 5 l'
#  'Bolsa naranjas 2Kg.' 'Mandarina' 'Melo  OR' 'Jamón reserva'
#  'Naranja en cajas' 'Pack de plátanos'
#  'MERLUZA PALANGRE 1 - 2 Kg (1 Caja 10Q.)' 'Tomate jugoso al peso'
#  'Filetes de salmón' 'Sepia' 'Fresa premium 500gr']

# %% [markdown]
# **Usa una máscara para filtrar el artículo sobre el que queremos realizar las predicciones**

# %%
dataSku = dataRetail[dataRetail['Referencia']=='Naranja en cajas']
dataSku['Fecha'] = pd.to_datetime(dataSku['Fecha'], format='%Y-%m-%d')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ** Ya que hemos cogido un producto que tiene huecos vamos a hacer una limpieza del dataframe ya que esos huecos originarían errores más tarde**

# %%
dataSku=dataSku.set_index('Fecha')

# %%
fechaMin = dataSku.index.min()
print(fechaMin)
# Out:
# 2017-01-02 00:00:00

# %%
fechaMax = dataSku.index.max()
print(fechaMax)
# Out:
# 2019-05-18 00:00:00

# %%
range = pd.date_range(start=fechaMin, end=fechaMax,freq='d')
dataSku = dataSku.reindex(range)
dataSku['Unidades']=dataSku['Unidades'].fillna(value=0)
dataSku['Ventas']=dataSku['Ventas'].fillna(value=0)
dataSku['Referencia']=dataSku['Referencia'].fillna(method='ffill')
dataSku=dataSku.reset_index()
dataSku=dataSku.rename(columns={'index':'Fecha Format'})
#dataSku['OffsetDays']=dataSku['OffsetDays'].astype(int)
dataSku['OffsetDays'] = dataSku.index

# %%
dataSku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 867 entries, 0 to 866
# Data columns (total 5 columns):
# Fecha Format    867 non-null datetime64[ns]
# Referencia      867 non-null object
# Unidades        867 non-null float64
# Ventas          867 non-null float64
# OffsetDays      867 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 34.0+ KB

# %%
dataSku.tail()
# Out:
#     Fecha Format        Referencia     Unidades       Ventas  OffsetDays
# 862   2019-05-14  Naranja en cajas   832.585002  1551.139998         862
# 863   2019-05-15  Naranja en cajas   763.860001  1423.989999         863
# 864   2019-05-16  Naranja en cajas   811.825001  1512.019999         864
# 865   2019-05-17  Naranja en cajas  1039.352002  1936.350002         865
# 866   2019-05-18  Naranja en cajas  1138.732000  2119.010001         866

# %%
dataSku.plot(x='Fecha Format', y='Ventas', figsize=(12,8), title='Ventas de Naranjas en Cajas')

# %% [markdown]
# ## 3. Prueba de la predicción sobre nuestras unidades vendidas con distintos modelos

# %% [markdown]
# ** Con la función de evaluación puedes probar el funcionamiento de distintos modelos**

# %%
def rmsle(ytrue, ypred):
    return np.sqrt(mean_squared_log_error(ytrue, ypred))
def calculoEvaluacionModelo(modelo,df,norm):

    xPredicted = []
    yPredicted = []
    ySpotted = []
    mean_error = []

    for day in np.arange(800,861):
        train = df[df['OffsetDays'] < day]
        val = df[df['OffsetDays'] == day]       
        
        xtr, xts = train.drop(['Unidades'], axis=1), val.drop(['Unidades'], axis=1)
        
        if(norm==True):
            sc = StandardScaler()  
            xtr = sc.fit_transform(xtr)  
            xts = sc.transform(xts)  
        ytr, yts = train['Unidades'].values, val['Unidades'].values  

        mdl = modelo
        mdl.fit(xtr, ytr)

        p = mdl.predict(xts)

        xPredicted=xPredicted + [day]
        yPredicted=yPredicted + [p[0]]
        ySpotted = ySpotted + [yts[0]]

        error = rmsle(yts, p)
        print('Month %d - Error %.5f' % (day, error))
        mean_error.append(error)

    print('Mean Error = %.5f' % np.mean(mean_error))
    prediction = pd.DataFrame(
        {'Sold units predicted': yPredicted,
         'Sold units actually spotted': ySpotted
        },index=xPredicted)
    prediction.plot()

# %% [markdown]
# ** Elige el modelo que más te haya gustado o mejor haya funcionado e hiperparametrizalo si quieres**

# %%
norma=False
dataSku_simple = dataSku[['OffsetDays','Unidades']].copy()
dataSku_simple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 867 entries, 0 to 866
# Data columns (total 2 columns):
# OffsetDays    867 non-null int64
# Unidades      867 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 13.7 KB

# %%
from sklearn.linear_model import LinearRegression
calculoEvaluacionModelo(LinearRegression(),dataSku_simple,norma)
# Out:
# Month 800 - Error 0.18057
# Month 801 - Error 0.36222
# Month 802 - Error 0.62211
# Month 803 - Error 0.62249
# Month 804 - Error 3.97880
# Month 805 - Error 0.47639
# Month 806 - Error 0.24290
# Month 807 - Error 0.20399
# Month 808 - Error 0.21353
# Month 809 - Error 0.61956
# Month 810 - Error 0.58505
# Month 811 - Error 4.02730
# Month 812 - Error 0.38456
# Month 813 - Error 0.23019
# Month 814 - Error 0.23380
# Month 815 - Error 0.25158
# Month 816 - Error 0.57035
# Month 817 - Error 0.59176
# Month 818 - Error 4.05031
# Month 819 - Error 0.37221
# Month 820 - Error 0.71044
# Month 821 - Error 0.52804
# Month 822 - Error 0.58245
# Month 823 - Error 0.83365
# Month 824 - Error 1.01897
# Month 825 - Error 3.45776
# Month 826 - Error 0.61660
# Month 827 - Error 0.28550
# Month 828 - Error 0.06411
# Month 829 - Error 0.18488
# Month 830 - Error 0.45729
# Month 831 - Error 0.50397
# Month 832 - Error 3.54472
# Month 833 - Error 0.24694
# Month 834 - Error 0.29672
# Month 846 - Error 4.24272
# Month 847 - Error 0.34230
# Month 848 - Error 0.63832
# Month 849 - Error 3.73848
# Month 850 - Error 0.41794
# Month 851 - Error 0.53831
# Month 852 - Error 0.55312
# Month 853 - Error 4.23611
# Month 854 - Error 0.19771
# Month 855 - Error 0.11591
# Month 856 - Error 0.07740
# Month 857 - Error 0.07289
# Month 858 - Error 0.57352
# Month 859 - Error 0.08970
# Month 860 - Error 3.58154
# Mean Error = 1.03016

# %%
from sklearn.neural_network import MLPRegressor
calculoEvaluacionModelo(MLPRegressor(random_state=1976,max_iter=200),dataSku_simple,norma)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 800 - Error 0.03129
# Month 801 - Error 0.06374
# Month 802 - Error 0.16562
# Month 803 - Error 0.27568
# Month 804 - Error 4.33324
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 805 - Error 0.33302
# Month 806 - Error 0.04840
# Month 807 - Error 0.04786
# Month 808 - Error 0.22096
# Month 809 - Error 0.27965
# Month 810 - Error 0.18248
# Month 811 - Error 4.25393
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 812 - Error 0.16751
# Month 813 - Error 0.01941
# Month 814 - Error 0.08266
# Month 815 - Error 0.05113
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 816 - Error 0.39499
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:568: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# Month 817 - Error 0.40260
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:568: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# Month 818 - Error 4.35561
# Month 819 - Error 0.18716
# Month 820 - Error 0.56451
# Month 821 - Error 0.31675
# Month 822 - Error 0.33145
# Month 823 - Error 0.65357
# Month 824 - Error 0.87440
# Month 825 - Error 3.66959
# Month 826 - Error 0.45033
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 827 - Error 0.09872
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 828 - Error 0.09415
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 829 - Error 0.04139
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 830 - Error 0.23075
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 831 - Error 0.31651
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 832 - Error 3.70723
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 833 - Error 0.06819
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 834 - Error 0.13486
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 835 - Error 0.17251
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 836 - Error 0.64169
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 837 - Error 2.77131
# Month 838 - Error 0.50700
# Month 839 - Error 2.96900
# Month 840 - Error 2.63309
# Month 841 - Error 0.36445
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 842 - Error 0.25110
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 843 - Error 0.12072
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 844 - Error 0.38751
# Month 845 - Error 0.39512
# Month 846 - Error 4.42716
# Month 847 - Error 0.18029
# Month 848 - Error 0.43896
# Month 849 - Error 3.96346
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 850 - Error 0.23556
# Month 851 - Error 0.36476
# Month 852 - Error 0.36208
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Month 853 - Error 4.42988
# Month 854 - Error 0.00654
# Month 855 - Error 0.06871
# Month 856 - Error 0.11193
# Month 857 - Error 0.15002
# Month 858 - Error 0.38540
# Month 859 - Error 0.29139
# Month 860 - Error 3.75907
# Mean Error = 0.94816

# %%
# El modelo con mejor prediccion es el RandomForestRegressor
# Es de notar que aunque el Mean Error de este modelo comparado con los otros es similar, la prediccion se ajusta
# mucho mas a los valores originales

# %% [markdown]
# ## 4. Complementar el dataframe con variables sintéticas

# %% [markdown]
# ** En base a lo que hayas observado en el comportamiento de las unidades vendidas de tu referencia crea variables sintéticas que creas que ayuden al modelo a mejorar la predicción**

# %%
# Creamos como variables sinteticas 'Lags y diferencias'

dataSku_simple2 = dataSku_simple.copy()
dataSku_simple2['Unidades_prev'] = dataSku_simple2['Unidades'].shift()
dataSku_simple2['Unidades_Diff'] = dataSku_simple2['Unidades_prev'].diff()
dataSku_simple2.head(10)
# Out:
#    OffsetDays     Unidades  Unidades_prev  Unidades_Diff
# 0           0   831.050001            NaN            NaN
# 1           1   905.089000     831.050001            NaN
# 2           2  1038.833999     905.089000      74.038998
# 3           3  1201.143999    1038.833999     133.745000
# 4           4     0.000000    1201.143999     162.309999
# 5           5  1538.045000       0.000000   -1201.143999
# 6           6    21.250000    1538.045000    1538.045000
# 7           7  1160.828000      21.250000   -1516.795000
# 8           8  1085.319000    1160.828000    1139.578000
# 9           9   823.631000    1085.319000     -75.509000

# %%
# Eliminamos los NaN del principio cuando se crean las variables sinteticas
dataSku_simple2 = dataSku_simple2.dropna()

# %%
from sklearn.ensemble import RandomForestRegressor
calculoEvaluacionModelo(RandomForestRegressor(),dataSku_simple2,norma)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Month 800 - Error 0.25226
# Month 801 - Error 0.00976
# Month 802 - Error 0.20051
# Month 803 - Error 0.25013
# Month 804 - Error 4.28309
# Month 805 - Error 0.22199
# Month 806 - Error 0.04569
# Month 807 - Error 0.15270
# Month 808 - Error 0.25139
# Month 809 - Error 0.12578
# Month 810 - Error 0.11442
# Month 811 - Error 3.99418
# Month 812 - Error 0.10226
# Month 813 - Error 0.14044
# Month 814 - Error 0.01615
# Month 815 - Error 0.34112
# Month 816 - Error 0.20387
# Month 817 - Error 0.04138
# Month 818 - Error 3.57310
# Month 819 - Error 0.21760
# Month 820 - Error 0.46276
# Month 821 - Error 0.16743
# Month 822 - Error 0.10558
# Month 823 - Error 4.80716
# Month 824 - Error 0.32698
# Month 825 - Error 4.37040
# Month 826 - Error 0.16262
# Month 827 - Error 1.00285
# Month 828 - Error 0.24706
# Month 829 - Error 0.10504
# Month 830 - Error 0.21626
# Month 831 - Error 0.08454
# Month 832 - Error 4.08084
# Month 833 - Error 0.07072
# Month 834 - Error 0.12455
# Month 835 - Error 0.01041
# Month 836 - Error 0.46000
# Month 837 - Error 3.04841
# Month 838 - Error 0.14695
# Month 839 - Error 2.76657
# Month 840 - Error 3.07186
# Month 841 - Error 0.25207
# Month 842 - Error 0.59686
# Month 843 - Error 0.28605
# Month 844 - Error 0.32528
# Month 845 - Error 0.27733
# Month 846 - Error 0.12966
# Month 847 - Error 0.02023
# Month 848 - Error 0.30277
# Month 849 - Error 4.31967
# Month 850 - Error 0.14283
# Month 851 - Error 0.03664
# Month 852 - Error 0.70814
# Month 853 - Error 3.34105
# Month 854 - Error 0.12938
# Month 855 - Error 0.16311
# Month 856 - Error 0.38390
# Month 857 - Error 0.11669
# Month 858 - Error 0.23651
# Month 859 - Error 0.44915
# Month 860 - Error 4.04313
# Mean Error = 0.92848

# %%
dataSku_simple3 = dataSku_simple.copy()
dataSku_simple3['Unidades_prev'] = dataSku_simple3['Unidades'].shift()
dataSku_simple3['Unidades_prev_2'] = dataSku_simple3['Unidades'].shift(2)
dataSku_simple3['Unidades_prev_3'] = dataSku_simple3['Unidades'].shift(3)
dataSku_simple3['Unidades_prev_4'] = dataSku_simple3['Unidades'].shift(4)
dataSku_simple3['Unidades_Diff'] = dataSku_simple3['Unidades_prev'].diff()
dataSku_simple3['Unidades_Diff_2'] = dataSku_simple3['Unidades_prev'].diff(2)
dataSku_simple3['Unidades_Diff_3'] = dataSku_simple3['Unidades_prev'].diff(3)
dataSku_simple3['Unidades_Diff_4'] = dataSku_simple3['Unidades_prev'].diff(4)
dataSku_simple3 = dataSku_simple3.dropna()
dataSku_simple3.head()
# Out:
#    OffsetDays  Unidades  Unidades_prev  Unidades_prev_2  Unidades_prev_3  \
# 5           5  1538.045          0.000      1201.143999      1038.833999
# 6           6    21.250       1538.045         0.000000      1201.143999
# 7           7  1160.828         21.250      1538.045000         0.000000
# 8           8  1085.319       1160.828        21.250000      1538.045000
# 9           9   823.631       1085.319      1160.828000        21.250000
#
#    Unidades_prev_4  Unidades_Diff  Unidades_Diff_2  Unidades_Diff_3  \
# 5       905.089000   -1201.143999     -1038.833999      -905.089000
# 6      1038.833999    1538.045000       336.901001       499.211000
# 7      1201.143999   -1516.795000        21.250000     -1179.893999
# 8         0.000000    1139.578000      -377.217000      1160.828000
# 9      1538.045000     -75.509000      1064.069000      -452.726000
#
#    Unidades_Diff_4
# 5      -831.050001
# 6       632.956000
# 7     -1017.583999
# 8       -40.315998
# 9      1085.319000

# %%
from sklearn.ensemble import RandomForestRegressor
calculoEvaluacionModelo(RandomForestRegressor(),dataSku_simple3,norma)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Month 800 - Error 0.02070
# Month 801 - Error 0.13425
# Month 802 - Error 0.01825
# Month 803 - Error 0.01589
# Month 804 - Error 3.74007
# Month 805 - Error 0.06590
# Month 806 - Error 0.16753
# Month 807 - Error 0.03629
# Month 808 - Error 0.10928
# Month 809 - Error 0.08976
# Month 810 - Error 0.81937
# Month 811 - Error 3.72531
# Month 812 - Error 0.03986
# Month 813 - Error 0.09362
# Month 814 - Error 0.04025
# Month 815 - Error 0.04951
# Month 816 - Error 0.02033
# Month 817 - Error 0.02817
# Month 818 - Error 3.50088
# Month 819 - Error 0.02469
# Month 820 - Error 0.44800
# Month 821 - Error 0.27404
# Month 822 - Error 0.11026
# Month 823 - Error 1.29497
# Month 824 - Error 0.38529
# Month 825 - Error 1.92733
# Month 826 - Error 0.02463
# Month 827 - Error 0.05310
# Month 828 - Error 0.14724
# Month 829 - Error 0.04495
# Month 830 - Error 0.07483
# Month 831 - Error 0.03190
# Month 832 - Error 2.08097
# Month 833 - Error 0.02299
# Month 834 - Error 0.08036
# Month 835 - Error 0.23591
# Month 836 - Error 0.54771
# Month 837 - Error 2.49142
# Month 838 - Error 0.44976
# Month 839 - Error 3.28260
# Month 840 - Error 2.48947
# Month 841 - Error 0.01607
# Month 842 - Error 0.14412
# Month 843 - Error 0.22124
# Month 844 - Error 0.07114
# Month 845 - Error 0.12564
# Month 846 - Error 4.16563
# Month 847 - Error 0.14594
# Month 848 - Error 0.09892
# Month 849 - Error 3.19687
# Month 850 - Error 0.08467
# Month 851 - Error 0.17134
# Month 852 - Error 0.64191
# Month 853 - Error 4.64901
# Month 854 - Error 0.23675
# Month 855 - Error 0.18607
# Month 856 - Error 0.05625
# Month 857 - Error 0.08447
# Month 858 - Error 0.10536
# Month 859 - Error 0.31399
# Month 860 - Error 3.48532
# Mean Error = 0.77768
